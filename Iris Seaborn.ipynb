# %%
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

df = pd.read_csv("iris.csv")

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.regplot(x= 'sepal_length', y= 'sepal_width', data = df)
print(df.corr()['sepal_length']['sepal_width'])
plt.show()
# Out:
# -0.10936924995064935

# %%
sns.jointplot('sepal_length', 'sepal_width', data = df, kind = 'reg')
print('The correlation is ', df.corr()['sepal_length']['sepal_width'])
plt.show()
# Out:
# The correlation is  -0.10936924995064935

# %%
iris = sns.load_dataset("iris")
g = sns.pairplot(iris, hue = 'species')
df.corr().style.background_gradient(cmap='Blues').format("{:.2f}")
# Out:
# <style  type="text/css" >
#     #T_244f2006_e084_11ea_8a50_85dd10f95371row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_244f2006_e084_11ea_8a50_85dd10f95371row0_col1 {
#             background-color:  #ccdff1;
#             color:  #000000;
#         }    #T_244f2006_e084_11ea_8a50_85dd10f95371row0_col2 {
#             background-color:  #08488e;
#             color:  #f1f1f1;
#         }    #T_244f2006_e084_11ea_8a50_85dd10f95371row0_col3 {
#             background-color:  #0a539e;
#             color:  #f1f1f1;
#         }    #T_244f2006_e084_11ea_8a50_85dd10f95371row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_244f2006_e084_11ea_8a50_85dd10f95371row1_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_244f2006_e084_11ea_8a50_85dd10f95371row1_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
# ...

# %%
g = sns.pairplot(iris,  hue = 'species', 
                 vars = ['sepal_width', 'sepal_length'])

# %%
sns.boxplot(df['petal_length'])
sns.swarmplot(df['petal_length'],hue = df['species'], color= 'r')
plt.axvline(df['petal_length'].mean(), 0, color = 'green')
plt.xlabel('Petal Length')
plt.title('Box Plot of petal length')
plt.show()

# %%
fig, axis = plt.subplots(3,2, figsize = (12,7))

sns.catplot(x = 'petal_length', data = iris, ax= axis[0,0], kind = 'box')
sns.stripplot(x = 'petal_length',color = 'r', data =iris, ax= axis[0,0],jitter = False)

sns.catplot(x = 'petal_length', data = iris, ax= axis[0,1], kind = 'box')
sns.swarmplot(x = 'petal_length',color = 'r', data =iris, ax= axis[0,1])

sns.catplot(data = iris, x = 'petal_length', y = 'species', kind = 'bar', ax= axis[1,0])
sns.catplot(data = iris, x = 'petal_length', y = 'species', kind = 'box', ax = axis[1,1])
sns.distplot(df['petal_length'], ax = axis[2,0] )
plt.show()

# %%
sns.catplot(x = 'species', y = 'petal_length', data = iris, kind= 'bar')

# %%
sns.catplot(x = 'species', y = 'petal_length', data = iris, kind= 'bar')

# %%
df.corr().style.background_gradient(cmap='Blues').format("{:.2f}")
# Out:
# <style  type="text/css" >
#     #T_f177381c_ba45_11ea_ba7d_ad7bd0f3c1e5row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_f177381c_ba45_11ea_ba7d_ad7bd0f3c1e5row0_col1 {
#             background-color:  #ccdff1;
#             color:  #000000;
#         }    #T_f177381c_ba45_11ea_ba7d_ad7bd0f3c1e5row0_col2 {
#             background-color:  #08488e;
#             color:  #f1f1f1;
#         }    #T_f177381c_ba45_11ea_ba7d_ad7bd0f3c1e5row0_col3 {
#             background-color:  #0a539e;
#             color:  #f1f1f1;
#         }    #T_f177381c_ba45_11ea_ba7d_ad7bd0f3c1e5row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_f177381c_ba45_11ea_ba7d_ad7bd0f3c1e5row1_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_f177381c_ba45_11ea_ba7d_ad7bd0f3c1e5row1_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
# ...

# %%
g = sns.FacetGrid(df, row = 'species')
g = g.map(plt.hist, 'sepal_length')
plt.grid()
plt.show()

# %%
sns.relplot(x ='petal_length',y = 'petal_width', data = iris, size = 'sepal_length', sizes=(5,50) ,hue = 'species')
sns.relplot(x ='petal_length',y = 'petal_width', data = iris, col = 'species')
print('The correlation is',df.corr()['petal_length']['petal_width'])
# Out:
# The correlation is 0.9627570970509667

# %%
sns.boxplot(data = df)

# %%
import seaborn as sns
sns.boxplot(data = iris)
sns.swarmplot(data =  iris, color = 'black')
import matplotlib.pyplot as plt
plt.ylabel('Centimeters ')
plt.title('BoxPlot of Flower Variables')
# Out:
# Text(0.5, 1.0, 'BoxPlot of Flower Variables')

# %%
sns.boxplot(data = iris, x = 'petal_width', y = 'species')

# %%
a = df.corr()['sepal_length']

# %%
print(a)
# Out:
# sepal_length    1.000000
# sepal_width    -0.109369
# petal_length    0.871754
# petal_width     0.817954
# Name: sepal_length, dtype: float64

# %%
iris.boxplot(by = 'species', figsize = (10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002A501945CF8>,
# ...
#       dtype=object)

# %%
iris.hist(edgecolor='black', linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(12,6)

# %%
df.plot.hist(subplots = True, layout = (2,2),edgecolor = 'black', figsize = (10,10), bins= 15)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002A502434278>,
# ...
#       dtype=object)

# %%
sns.relplot(x ='petal_length',y = 'petal_width', data = df, size = 'sepal_length', sizes=(5,50) ,hue = 'species')

print('The correlation is',df.corr()['petal_length']['petal_width'])
# Out:
# The correlation is 0.9627570970509667

# %%
iris = sns.load_dataset("iris")
g = sns.pairplot(iris, hue = 'species')
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
#ML libraries
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification 
import numpy as np
iris = datasets.load_iris()

# %%
x = iris.data 
y = iris.target

# %%
#Random Forest classification
clf = RandomForestClassifier()
clf.fit(x, y)
clf.fit(iris.data, iris.target_names[iris.target])
# Out:
# C:\Users\colli\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
print(clf.feature_importances_)
print(iris.feature_names)
# Out:
# [0.07265993 0.01354543 0.45835092 0.45544372]
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
x.shape
# Out:
# (150, 4)

# %%
y.shape
# Out:
# (150,)

# %%
#See if model predicts the correct species for existing data
x[4]
# Out:
# array([5. , 3.6, 1.4, 0.2])

# %%
print(clf.predict(x[[4]]))
df.head(4)
# Out:
# ['setosa']
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa

# %%
print(clf.predict_proba(x[[4]]))
# Out:
# [[1. 0. 0.]]
